# %% [markdown]
# # Multi-Modal Self-Supervised Learning Demo
#
# This notebook demonstrates the multi-modal self-supervised learning model using CLIP-style contrastive learning.
#
# ## Overview
#
# The model learns to associate images with text descriptions through contrastive learning, without requiring explicit supervision. It uses dual encoders (vision and text) with a contrastive loss function.

# %%
# Import necessary libraries
import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# Import our modules
from src.models.clip_model import ContrastiveCLIPModel, ContrastiveLoss
from src.data.dataset import ToyMultimodalDataset, create_data_splits
from src.eval.metrics import compute_contrastive_metrics
from src.utils.device import setup_device_and_seed
from src.utils.config import load_config

# Set up plotting
plt.style.use('default')
sns.set_palette("husl")

print("Libraries imported successfully!")
